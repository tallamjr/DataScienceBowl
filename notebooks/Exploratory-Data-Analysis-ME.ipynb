# %% [markdown]
# # Exploratory Data Analysis
#
# The objective of this notebook is to explore the data and investigate the type of methods that might be well suited to this task

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import dicom
import subprocess as sp

# Choose random image from dataset
test_image = "../data/stage1/large/0015ceb851d7251b8f399e39779d1e7d/00ac2629fe659e68f4879da4812af659.dcm"

dc = dicom.read_file(test_image)
img = dc.pixel_array
plt.imshow(img,cmap='gray') # assuming img is one slice
